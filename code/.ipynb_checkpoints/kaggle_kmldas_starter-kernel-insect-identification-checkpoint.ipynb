# %% [markdown]
# # Insect Identification & Classification Project

# %% [markdown]
# This is an image classification problem of 291 species of Insects using  63,364 images from the Natural History Museum London
#
# Source: https://zenodo.org/record/3549369#.XvI_jMfVLIU

# %% [markdown]
# #  Import Libraries

# %%
import os
import torch
import pandas as pd
import numpy as np
import seaborn as sns
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

import random
import time

from torch.utils.data import Dataset, random_split, DataLoader
from PIL import Image
import torchvision.models as models
from tqdm.notebook import tqdm
import torchvision.transforms as T

from sklearn.metrics import f1_score
import torch.nn.functional as F
import torch.nn as nn
from torchvision.utils import make_grid

# %% [markdown]
# # Read the data

# %%
# Load the paths to the images in a directory

def load_images_from_folder(folder,only_path = False, label = ""):
    if only_path == False:
        images = []
        file_name=[]
        for filename in os.listdir(folder):
            img = plt.imread(os.path.join(folder,filename))
            
            if img is not None:
                end=filename.find(".")
                file_name.append(file[0:end])
                images.append(img)
                
        return images, file_name
    else:
        path = []
        for filename in os.listdir(folder):
            img_path = os.path.join(folder,filename)
            if img_path is not None:
                path.append([label,img_path])
        return path

# %% [markdown]
# # Set up the data and a label dictionary

# %%
# Load the paths on the images
images = []
path = "C:/Users/tomas/Desktop/kaggle_kmldas_habitus/database/"
for f in os.listdir(path):
    if "jpg" in os.listdir(path+f)[0]:
        images += load_images_from_folder(path+f,True,label = f)
      
    else: 
        for d in os.listdir(path+f):
            images += load_images_from_folder(path+f+"/"+d,True,label = f)
            
                        
# Create a dataframe with the paths and the label for each insect
df1 = pd.DataFrame(images, columns = ["insect_gbif", "path_img"])

file_name=[]
for i in range(len(df1["path_img"])):
    temp=df1.path_img[i].split('/')[-1].split('.')[0]
    file_name.append(temp)
file_name

df1['file_name'] = file_name
display(df1.describe())

display(df1)
# Out:
#        insect_gbif                                           path_img  \
# count        63364                                              63364
# unique         291                                              63364
# top        9364935  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# freq           888                                                  1
#
#                 file_name
# count               63364
# unique              63364
# top     1035167\d162s0011
# freq                    1
#       insect_gbif                                           path_img  \
# 0         1035167  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# 1         1035167  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# 2         1035167  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# 3         1035167  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# 4         1035167  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# ...           ...                                                ...
# 63359     9581584  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# 63360     9581584  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# 63361     9581584  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# 63362     9581584  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# 63363     9581584  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
#
#                file_name
# 0      1035167\d162s0011
# 1      1035167\d162s0012
# 2      1035167\d162s0013
# 3      1035167\d162s0014
# 4      1035167\d162s0015
# ...                  ...
# 63359  9581584\d135s0406
# 63360  9581584\d135s0407
# 63361  9581584\d135s0408
# 63362  9581584\d135s0409
# 63363  9581584\d135s0410
#
# [63364 rows x 3 columns]

# %%
labels = df1["insect_gbif"].unique()

labels_dict = dict(zip(range(len(labels)),labels))
labels_dict
# Out:
# {0: '1035167',
#  1: '1035185',
#  2: '1035194',
#  3: '1035195',
#  4: '1035204',
#  5: '1035208',
#  6: '1035231',
#  7: '1035290',
#  8: '1035366',
#  9: '1035434',
#  10: '1035542',
#  11: '1035551',
#  12: '1035578',
#  13: '1035864',
#  14: '1035929',
#  15: '1035931',
#  16: '1036066',
#  17: '1036128',
#  18: '1036154',
#  19: '1036192',
#  20: '1036203',
#  21: '1036216',
#  22: '1036255',
#  23: '1036286',
#  24: '1036789',
#  25: '1036796',
#  26: '1036893',
#  27: '1036899',
#  28: '1036917',
#  29: '1036958',
#  30: '1037293',
#  31: '1037319',
#  32: '1037633',
#  33: '4308786',
#  34: '4308787',
#  35: '4308789',
#  36: '4308790',
#  37: '4308800',
#  38: '4308801',
#  39: '4308804',
#  40: '4308805',
#  41: '4308806',
#  42: '4308807',
#  43: '4308811',
#  44: '4308812',
#  45: '4308815',
#  46: '4470539',
#  47: '4470555',
#  48: '4470765',
#  49: '4470801',
#  50: '4471071',
#  51: '4471113',
#  52: '4471202',
#  53: '4471235',
#  54: '4471238',
#  55: '4471269',
#  56: '4472828',
#  57: '4472849',
#  58: '4472858',
#  59: '4472884',
#  60: '4472897',
#  61: '4472900',
#  62: '4472907',
#  63: '4472913',
#  64: '4472929',
#  65: '4473127',
#  66: '4473277',
#  67: '4473297',
#  68: '4473319',
#  69: '4473320',
#  70: '4473617',
#  71: '4473795',
#  72: '4473834',
#  73: '4473860',
#  74: '4473874',
#  75: '4473903',
#  76: '4473974',
#  77: '4474146',
#  78: '4474169',
#  79: '4474653',
#  80: '4474780',
#  81: '4474861',
#  82: '4474974',
#  83: '4474998',
#  84: '4475099',
#  85: '4475127',
#  86: '4475128',
#  87: '4475140',
#  88: '4475157',
#  89: '4475179',
#  90: '4475181',
#  91: '4475188',
#  92: '4475213',
#  93: '4475677',
#  94: '4475685',
#  95: '4475707',
#  96: '4475757',
#  97: '4475761',
#  98: '4475794',
#  99: '4475846',
#  100: '4475902',
#  101: '4475908',
#  102: '4476667',
#  103: '4476832',
#  104: '4478057',
#  105: '4478679',
#  106: '4478695',
#  107: '4478699',
#  108: '4478842',
#  109: '4479052',
#  110: '4479870',
#  111: '4479890',
#  112: '4479895',
#  113: '4480200',
#  114: '4480271',
#  115: '4480302',
#  116: '4480315',
#  117: '4480348',
#  118: '4480480',
#  119: '4480485',
#  120: '4480502',
#  121: '4988207',
#  122: '4988354',
#  123: '4988363',
#  124: '4988447',
#  125: '4988484',
#  126: '4988516',
#  127: '5023047',
#  128: '5023058',
#  129: '5716406',
#  130: '5716408',
#  131: '5716409',
#  132: '5716411',
#  133: '5753612',
#  134: '5753653',
#  135: '5753697',
#  136: '5753720',
#  137: '5753725',
#  138: '5753757',
#  139: '5754974',
#  140: '5755011',
#  141: '5755027',
#  142: '5755044',
#  143: '5755051',
#  144: '5755060',
#  145: '5755066',
#  146: '5755075',
#  147: '5755079',
#  148: '5755080',
#  149: '5755082',
#  150: '5755175',
#  151: '5755203',
#  152: '5755293',
#  153: '5755296',
#  154: '5755302',
#  155: '5755322',
#  156: '5755339',
#  157: '5755451',
#  158: '5755456',
#  159: '5755562',
#  160: '5755950',
#  161: '5755952',
#  162: '5755954',
#  163: '5755969',
#  164: '5755978',
#  165: '5755982',
#  166: '5755986',
#  167: '5756010',
#  168: '5756015',
#  169: '5756018',
#  170: '5756021',
#  171: '5756368',
#  172: '5756374',
#  173: '5756814',
#  174: '5756874',
#  175: '5756945',
#  176: '5757120',
#  177: '5757155',
#  178: '5757192',
#  179: '5757205',
#  180: '5757207',
#  181: '5757211',
#  182: '5757304',
#  183: '5757308',
#  184: '5757310',
#  185: '5872109',
#  186: '5872111',
#  187: '5872119',
#  188: '5872124',
#  189: '5872127',
#  190: '5872129',
#  191: '5872143',
#  192: '5872147',
#  193: '5872148',
#  194: '5872219',
#  195: '5872829',
#  196: '5872954',
#  197: '5873211',
#  198: '5873214',
#  199: '5873215',
#  200: '5873218',
#  201: '5873220',
#  202: '5873271',
#  203: '5873357',
#  204: '5873524',
#  205: '5873525',
#  206: '6097854',
#  207: '6097857',
#  208: '6097861',
#  209: '6097862',
#  210: '6097864',
#  211: '6097865',
#  212: '6097867',
#  213: '6097868',
#  214: '6097869',
#  215: '6097871',
#  216: '6097872',
#  217: '6097878',
#  218: '6097879',
#  219: '6097882',
#  220: '6097883',
#  221: '6097885',
#  222: '6097886',
#  223: '6097890',
#  224: '6097892',
#  225: '6097896',
#  226: '6097897',
#  227: '6097900',
#  228: '6097906',
#  229: '6097912',
#  230: '6097923',
#  231: '6097924',
#  232: '6097926',
#  233: '6097927',
#  234: '6097930',
#  235: '7387665',
#  236: '7416497',
#  237: '7419401',
#  238: '7508714',
#  239: '7582513',
#  240: '7613168',
#  241: '7639821',
#  242: '7641814',
#  243: '7642452',
#  244: '7683246',
#  245: '7708350',
#  246: '7727698',
#  247: '7792354',
#  248: '7840196',
#  249: '7856746',
#  250: '7873810',
#  251: '7888598',
#  252: '7917481',
#  253: '7975487',
#  254: '8019310',
#  255: '8047965',
#  256: '8051076',
#  257: '8056040',
#  258: '8068514',
#  259: '8104778',
#  260: '8137203',
#  261: '8139233',
#  262: '8186956',
#  263: '8236590',
#  264: '8264200',
#  265: '8267077',
#  266: '8300237',
#  267: '8307815',
#  268: '8335452',
#  269: '8378220',
#  270: '8417764',
#  271: '8423772',
#  272: '8563753',
#  273: '8600499',
#  274: '8607776',
#  275: '9027622',
#  276: '9206709',
#  277: '9251010',
#  278: '9252314',
#  279: '9268484',
#  280: '9314786',
#  281: '9346940',
#  282: '9364935',
#  283: '9377664',
#  284: '9414758',
#  285: '9415910',
#  286: '9444427',
#  287: '9479706',
#  288: '9491931',
#  289: '9533851',
#  290: '9581584'}

# %% [markdown]
# # Exlporatory Data Analysis (EDA)

# %% [markdown]
# Let us look at the data and make some initial conclusions

# %%
num_images = len(df1["insect_gbif"])
print('Number of images are:', num_images)
no_labels=len(labels)
print('Number of insect species are:', no_labels)
# Out:
# Number of images are: 63364
# Number of insect species are: 291

# %% [markdown]
# Are images equally distributed between different insect species?
#
# Let's plot a graph and see!

# %%
bar = df1["insect_gbif"].value_counts(ascending=True).plot.barh(figsize = (30,120))
plt.title("Distribution of the insect species", fontsize = 20)
bar.tick_params(labelsize=16)
plt.show()

# %% [markdown]
# lets also make a table.. may be better as there are 200+ species

# %%
df1["insect_gbif"].value_counts()
# Out:
# 9364935    888
# 1035931    861
# 7508714    818
# 4475140    719
# 1036216    686
#           ...
# 4478057     53
# 4471238     52
# 5757120     52
# 4480271     52
# 4474780     50
# Name: insect_gbif, Length: 291, dtype: int64

# %% [markdown]
# It is a very unbalanced data. Some insect species have only 50 images, while others have 888!

# %% [markdown]
# # Split data into test, train and validation

# %%
train, validate, test = np.split(df1.sample(frac=1), [int(.6*len(df1)), int(.8*len(df1))])

display(train.describe())
display(validate.describe())
display(test.describe())
# Out:
#        insect_gbif                                           path_img  \
# count        38018                                              38018
# unique         291                                              38018
# top        9364935  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# freq           543                                                  1
#
#                 file_name
# count               38018
# unique              38018
# top     6097923\d184s0220
# freq                    1
#        insect_gbif                                           path_img  \
# count        12673                                              12673
# unique         291                                              12673
# top        7508714  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# freq           175                                                  1
#
#                 file_name
# count               12673
# unique              12673
# top     4475128\d187s0112
# freq                    1
#        insect_gbif                                           path_img  \
# count        12673                                              12673
# unique         291                                              12673
# top        9364935  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# freq           175                                                  1
#
#                 file_name
# count               12673
# unique              12673
# top     7975487\d122s0266
# freq                    1

# %% [markdown]
# Some may prefer only test abd validation
#
# you may combine two data sets- this will result in only train and validation set
#
# comment or delete the below code if you want three sets of data

# %%
df=train.append(test, ignore_index=True)
df.describe()
# Out:
#        insect_gbif                                           path_img  \
# count        50691                                              50691
# unique         291                                              50691
# top        9364935  C:/Users/tomas/Desktop/kaggle_kmldas_habitus/d...
# freq           718                                                  1
#
#                 file_name
# count               50691
# unique              50691
# top     6097923\d184s0220
# freq                    1

# %% [markdown]
# # Image Analysis

# %% [markdown]
# Let us display 20 picture of the dataset with their labels

# %%
# Shuffle the dataset
from sklearn.utils import shuffle
df = shuffle(df, random_state = 0)
df = df.reset_index(drop=True)

# Display 20 picture of the dataset with their labels
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(15, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df.path_img[i]))
    ax.set_title(df.insect_gbif[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# What do you observe?
#
# All images are of differnt sizes
#
# The backgrounsd vary a bit and as these are from a museum, there are the nals and other marks

# %% [markdown]
# # Image transforms using PyTorch

# %%
imagenet_stats = ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) #normalisation

train_tfms = T.Compose([
#this will resize the image 
    T.Resize((256,256)),   
   
#Randomly change the brightness, contrast and saturation of an image
#    T.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),    

#this will remove parts (crop) the Image at a random location.   
#    T.RandomCrop(32, padding=4, padding_mode='reflect'),   

#Horizontally flip (rotate by 180 degree) the given image randomly; default is 50% of images
    T.RandomHorizontalFlip(), 
    
#Rotate the image by angle -here by 10%
    T.RandomRotation(10),
    
#convert it to a tensor   
    T.ToTensor(),

#Normalize a tensor image with mean and standard deviation - here with the Imagenet stats
    T.Normalize(*imagenet_stats,inplace=True)
    
#Randomly selects a rectangle region in an image and erases its pixels.    
#    T.RandomErasing(inplace=True)
])

val_tfms = T.Compose([
#this will resize the image 
    T.Resize((256,256)),   
     
#convert it to a tensor   
    T.ToTensor(),

#Normalize a tensor image with mean and standard deviation - here with the Imagenet stats
    T.Normalize(*imagenet_stats,inplace=True)
    
])

# %%
class InsectDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform
        
        
    def __len__(self):
        return len(self.df)    
    
    def __getitem__(self, idx):
        row = self.df.loc[idx]
        img_id, img_label = row['path_img'], row['insect_gbif']
        img = Image.open(img_id)
        if self.transform:
            img = self.transform(img)
        return img, img_label

# %%
train_ds = InsectDataset(train,transform=train_tfms)
val_ds = InsectDataset(validate, transform=val_tfms)
print("finished")
# Out:
# finished

# %%
def show_sample(img, target, invert=True):
    if invert:
        plt.imshow(1 - img.permute((1, 2, 0)))
    else:
        plt.imshow(img.permute(1, 2, 0))
    print('Labels:', target)

# %% [markdown]
# # View Sample Images after Transform

# %%
show_sample(*train_ds[229])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Labels: 1035185

# %%
show_sample(*train_ds[229], invert= False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Labels: 1035185

# %% [markdown]
# # Lets GO!!

# %% [markdown]
# Lets make an image classification model! Hope this is a good starter for you!
#
# Thanks and all the best!
